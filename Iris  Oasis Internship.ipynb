# %% [markdown]
# ![iris_flower_sepal_and_petal.png](attachment:iris_flower_sepal_and_petal.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.drop(['Id'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['SepalLengthCm'].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.5     7
# 5.8     7
# 6.4     7
# 6.0     6
# 4.9     6
# 6.1     6
# 5.4     6
# 5.6     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 5.2     4
# 6.2     4
# 4.6     4
# 7.2     3
# 6.8     3
# 4.4     3
# 5.9     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 4.3     1
# 7.9     1
# 7.3     1
# 7.0     1
# 4.5     1
# 5.3     1
# 7.1     1
# Name: SepalLengthCm, dtype: int64

# %%
df['SepalLengthCm'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
plt.figure(figsize=(15,6))
sns.countplot(x =df['SepalLengthCm'], data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df['SepalLengthCm'].value_counts(), labels=df['SepalLengthCm'].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('SepalLengthCm', size=20, **hfont) 
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x =df['SepalWidthCm'], data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df['SepalWidthCm'].value_counts(), labels=df['SepalWidthCm'].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('SepalwidthCm', size=20, **hfont) 
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x =df['PetalLengthCm'], data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df['PetalLengthCm'].value_counts(), labels=df['PetalLengthCm'].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('PetallengthCm', size=20, **hfont) 
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x =df['PetalWidthCm'], data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df['PetalWidthCm'].value_counts(), labels=df['PetalWidthCm'].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('PetalWidthCm', size=20, **hfont) 
plt.show()

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
numeric_df = df.select_dtypes(include=['float64'])

# %%
numeric_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
for i in numeric_df.columns:
    plt.figure(figsize=(15,6))
    sns.violinplot(numeric_df[i], palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in numeric_df.columns:
    plt.figure(figsize=(15,6))
    sns.boxenplot(numeric_df[i], palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in numeric_df.columns:
    plt.figure(figsize=(15,6))
    sns.histplot(numeric_df[i],kde= True,bins=20, palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()

# %%
for i in df.columns:
    for j in df.columns:
        if i != j:
            if i != 'Species':
                plt.figure(figsize=(15,6))
                sns.scatterplot(x = df[i], y = df[j], data = df,palette = 'hls')
                plt.xticks(rotation = 90)
                plt.show()

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize=(10, 8))
matrix = np.triu(df_corr)
sns.heatmap(df_corr, annot=True, linewidth=.8, mask=matrix, cmap="rocket");
plt.show()

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
from sklearn import preprocessing

for col in df.select_dtypes(include=['object']).columns:
    
    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(df[col].unique())
    df[col] = label_encoder.transform(df[col])
    print(f"{col}: {df[col].unique()}")
# Out:
# Species: [0 1 2]

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),fmt='.2g',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X = df.drop('Species',axis=1)
y =df['Species']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 137            6.4           3.1            5.5           1.8
# 84             5.4           3.0            4.5           1.5
# 27             5.2           3.5            1.5           0.2
# 127            6.1           3.0            4.9           1.8
# 132            6.4           2.8            5.6           2.2
# ..             ...           ...            ...           ...
# 9              4.9           3.1            1.5           0.1
# 103            6.3           2.9            5.6           1.8
# 67             5.8           2.7            4.1           1.0
# 117            7.7           3.8            6.7           2.2
# 47             4.6           3.2            1.4           0.2
#
# [120 rows x 4 columns]

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %%
y_train
# Out:
# 137    2
# 84     1
# 27     0
# 127    2
# 132    2
#       ..
# 9      0
# 103    2
# 67     1
# 117    2
# 47     0
# Name: Species, Length: 120, dtype: int32

# %%
y_test
# Out:
# 114    2
# 62     1
# 33     0
# 107    2
# 7      0
# 100    2
# 40     0
# 86     1
# 76     1
# 71     1
# 134    2
# 51     1
# 73     1
# 54     1
# 63     1
# 37     0
# 78     1
# 90     1
# 45     0
# 16     0
# 121    2
# 66     1
# 24     0
# 8      0
# 126    2
# 22     0
# 44     0
# 97     1
# 93     1
# 26     0
# Name: Species, dtype: int32

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X_train,y_train)
y_hat=LR.predict(X_test)

# %%
y_train_predict=LR.predict(X_train)
from sklearn.metrics import r2_score
train_score=r2_score(y_train,y_train_predict)
train_score
# Out:
# 0.9339533279460861

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
svm = SVR()
svm.fit(X_train,y_train)
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
gr = GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = rf.predict(X_test)
y_pred4 = gr.predict(X_test)



df1 = pd.DataFrame({'Actual':y_test,'LR':y_pred1,'svm':y_pred2,'rf':y_pred3,'gr':y_pred4})

# %%
df1
# Out:
#      Actual        LR       svm    rf        gr
# 114       2  2.067039  2.042151  2.00  1.981071
# 62        1  0.964881  0.943878  1.06  0.960906
# 33        0 -0.145942 -0.013954  0.00  0.000938
# 107       2  1.813731  2.003663  2.00  2.005095
# 7         0 -0.037808 -0.002094  0.00 -0.000061
# 100       2  2.261369  2.249052  2.00  2.010493
# 40        0 -0.026842  0.008342  0.00 -0.000061
# 86        1  1.319556  1.293901  1.00  1.013696
# 76        1  1.283001  1.331098  1.09  1.012807
# 71        1  1.112890  0.957142  1.00  1.030117
# 134       2  1.549098  1.837314  1.57  1.756163
# 51        1  1.301540  1.208310  1.00  0.968744
# 73        1  1.212710  1.280119  1.00  1.042866
# 54        1  1.329869  1.315365  1.02  1.078242
# 63        1  1.330475  1.359270  1.00  1.039830
# 37        0 -0.076054  0.011858  0.00 -0.000061
# 78        1  1.356077  1.314034  1.01  1.138493
# 90        1  1.215640  1.241456  1.00  1.001498
# 45        0  0.037389  0.051727  0.00  0.000572
# ...

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['LR'].iloc[0:11],label="LR")
plt.legend()


plt.subplot(222)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['svm'].iloc[0:11],label="svm")
plt.legend()

plt.subplot(223)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['rf'].iloc[0:11],label="rf")
plt.legend()


plt.subplot(224)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['gr'].iloc[0:11],label="gr")

plt.tight_layout()


plt.legend()

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)
y_predict
# Out:
# array([ 2.06703909,  0.96488074, -0.14594224,  1.81373137, -0.03780827,
#         2.26136881, -0.02684168,  1.3195563 ,  1.28300114,  1.11288966,
#         1.54909827,  1.30153965,  1.2127103 ,  1.32986888,  1.33047544,
#        -0.07605449,  1.35607655,  1.21563955,  0.0373887 , -0.02449662,
#         1.79885764,  1.3946086 ,  0.07528911,  0.02303999,  1.59033372,
#        -0.11806588,  0.14915066,  1.1671282 ,  0.90650885,  0.10691577])

# %%
test_score=r2_score(y_test,y_hat)
test_score
# Out:
# 0.9059663899067814

# %%
X_train.shape,X_test.shape
# Out:
# ((120, 4), (30, 4))

# %%
sns.pairplot(df)

# %%
# model training

# linear regression

regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True,fit_intercept= True,n_jobs=None,normalize=False)
# Out:
# LinearRegression()

# %%
training_data_prediction = regressor.predict(X_train)

# %%
from sklearn import metrics

# %%
r2_train = metrics.r2_score(y_train,training_data_prediction)
print('R squared value :',r2_train)
# Out:
# R squared value : 0.9339533279460861

# %%
test_data_prediction = regressor.predict(X_test)

# %%
r2_test= metrics.r2_score(y_test,test_data_prediction)
print('R squared value :',r2_test)
# Out:
# R squared value : 0.9059663899067814

# %% [markdown]
# ## Building a predictive system

# %%
input_data = (5.1,3.5 ,1.4,0.2)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)
# Out:
# [-0.07540049]

# %%
print('The Species of colour',prediction[0])
# Out:
# The Species of colour -0.07540048519068354

# %%
if(prediction[0])==0:
    print('The Species of colour is Iris-setosa')
elif:
    print('The Species of colour is Iris-Iris-versicolor')    
else :
    print('The Species of colour is Iris-Iris-virginica')
# Out:
#   File "<ipython-input-78-94a586aee4e3>", line 3
#     elif:
#         ^
# SyntaxError: invalid syntax
